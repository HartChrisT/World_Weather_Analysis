# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pprint import pprint
import requests
import json
from citipy import citipy
import time
from datetime import datetime
# Import API Key
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000,high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval       ")
print("-------------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -------------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | le port
# Processing Record 2 of Set 1 | mecca
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | barrow
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | fuling
# Processing Record 7 of Set 1 | borlange
# City not found. Skipping...
# Processing Record 8 of Set 1 | belchatow
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | haines junction
# Processing Record 11 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 1 | kathmandu
# Processing Record 13 of Set 1 | sola
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | victoria
# Processing Record 16 of Set 1 | bousso
# Processing Record 17 of Set 1 | provideniya
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | port lincoln
# Processing Record 20 of Set 1 | vitim
# Processing Record 21 of Set 1 | butaritari
# Processing Record 22 of Set 1 | rybachiy
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | khatanga
# Processing Record 25 of Set 1 | plettenberg bay
# Processing Record 26 of Set 1 | kahului
# Processing Record 27 of Set 1 | lakeside
# Processing Record 28 of Set 1 | havelock
# Processing Record 29 of Set 1 | caserta
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | georgetown
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 34 of Set 1 | los llanos de aridane
# Processing Record 35 of Set 1 | castro
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | arraial do cabo
# Processing Record 40 of Set 1 | rabo de peixe
# Processing Record 41 of Set 1 | buta
# Processing Record 42 of Set 1 | nioro
# Processing Record 43 of Set 1 | tuktoyaktuk
# Processing Record 44 of Set 1 | yangambi
# Processing Record 45 of Set 1 | puerto ayora
# Processing Record 46 of Set 1 | albany
# Processing Record 47 of Set 1 | chokurdakh
# Processing Record 48 of Set 1 | balclutha
# Processing Record 49 of Set 1 | ouesso
# Processing Record 50 of Set 1 | saint george
# Processing Record 1 of Set 2 | burgersdorp
# Processing Record 2 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 2 | port hawkesbury
# Processing Record 5 of Set 2 | coihaique
# Processing Record 6 of Set 2 | yellowknife
# Processing Record 7 of Set 2 | sarangani
# Processing Record 8 of Set 2 | umm jarr
# City not found. Skipping...
# Processing Record 9 of Set 2 | ponta do sol
# Processing Record 10 of Set 2 | suileng
# Processing Record 11 of Set 2 | dikson
# Processing Record 12 of Set 2 | tiksi
# Processing Record 13 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 2 | atuona
# Processing Record 15 of Set 2 | grindavik
# Processing Record 16 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 2 | itupiranga
# Processing Record 18 of Set 2 | bredasdorp
# Processing Record 19 of Set 2 | kanjiza
# Processing Record 20 of Set 2 | amapa
# Processing Record 21 of Set 2 | vardo
# Processing Record 22 of Set 2 | kilindoni
# Processing Record 23 of Set 2 | narsaq
# Processing Record 24 of Set 2 | karratha
# Processing Record 25 of Set 2 | krasnoarmeysk
# Processing Record 26 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 2 | te anau
# Processing Record 28 of Set 2 | oistins
# Processing Record 29 of Set 2 | hithadhoo
# Processing Record 30 of Set 2 | bambous virieux
# Processing Record 31 of Set 2 | ixtapa
# Processing Record 32 of Set 2 | kieta
# Processing Record 33 of Set 2 | alofi
# Processing Record 34 of Set 2 | kruisfontein
# Processing Record 35 of Set 2 | lagoa
# Processing Record 36 of Set 2 | upernavik
# Processing Record 37 of Set 2 | sur
# Processing Record 38 of Set 2 | avarua
# Processing Record 39 of Set 2 | jamestown
# Processing Record 40 of Set 2 | itoman
# Processing Record 41 of Set 2 | kokoda
# Processing Record 42 of Set 2 | camopi
# Processing Record 43 of Set 2 | belaya gora
# Processing Record 44 of Set 2 | brecht
# Processing Record 45 of Set 2 | udachnyy
# Processing Record 46 of Set 2 | salalah
# Processing Record 47 of Set 2 | cabedelo
# Processing Record 48 of Set 2 | praia
# Processing Record 49 of Set 2 | karauzyak
# City not found. Skipping...
# Processing Record 50 of Set 2 | new norfolk
# Processing Record 1 of Set 3 | cidreira
# Processing Record 2 of Set 3 | qaanaaq
# Processing Record 3 of Set 3 | cherskiy
# Processing Record 4 of Set 3 | kozhva
# Processing Record 5 of Set 3 | iqaluit
# Processing Record 6 of Set 3 | hilo
# Processing Record 7 of Set 3 | saint-augustin
# Processing Record 8 of Set 3 | bethel
# Processing Record 9 of Set 3 | nome
# Processing Record 10 of Set 3 | caravelas
# Processing Record 11 of Set 3 | gamba
# Processing Record 12 of Set 3 | tautira
# Processing Record 13 of Set 3 | grafton
# Processing Record 14 of Set 3 | nicoya
# Processing Record 15 of Set 3 | saskylakh
# Processing Record 16 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 17 of Set 3 | luderitz
# Processing Record 18 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 19 of Set 3 | vostok
# Processing Record 20 of Set 3 | zongolica
# Processing Record 21 of Set 3 | souillac
# Processing Record 22 of Set 3 | dali
# Processing Record 23 of Set 3 | mar del plata
# Processing Record 24 of Set 3 | tasiilaq
# Processing Record 25 of Set 3 | nyagan
# Processing Record 26 of Set 3 | parrita
# Processing Record 27 of Set 3 | hamilton
# Processing Record 28 of Set 3 | paamiut
# Processing Record 29 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 3 | bengkulu
# Processing Record 31 of Set 3 | ostrovnoy
# Processing Record 32 of Set 3 | leningradskiy
# Processing Record 33 of Set 3 | lahij
# Processing Record 34 of Set 3 | beringovskiy
# Processing Record 35 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 3 | nikolskoye
# Processing Record 37 of Set 3 | felidhoo
# City not found. Skipping...
# Processing Record 38 of Set 3 | wattegama
# Processing Record 39 of Set 3 | toftir
# City not found. Skipping...
# Processing Record 40 of Set 3 | saint-philippe
# Processing Record 41 of Set 3 | daru
# Processing Record 42 of Set 3 | kisangani
# Processing Record 43 of Set 3 | cockburn harbour
# City not found. Skipping...
# Processing Record 44 of Set 3 | cabo san lucas
# Processing Record 45 of Set 3 | ketchikan
# Processing Record 46 of Set 3 | moerai
# Processing Record 47 of Set 3 | piripiri
# Processing Record 48 of Set 3 | hay river
# Processing Record 49 of Set 3 | coquimbo
# Processing Record 50 of Set 3 | bathsheba
# Processing Record 1 of Set 4 | thompson
# Processing Record 2 of Set 4 | talaya
# Processing Record 3 of Set 4 | micheweni
# Processing Record 4 of Set 4 | margate
# Processing Record 5 of Set 4 | kapaa
# Processing Record 6 of Set 4 | choya
# Processing Record 7 of Set 4 | kodiak
# Processing Record 8 of Set 4 | cape town
# Processing Record 9 of Set 4 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 10 of Set 4 | oranjemund
# Processing Record 11 of Set 4 | faanui
# Processing Record 12 of Set 4 | mahebourg
# Processing Record 13 of Set 4 | cap malheureux
# Processing Record 14 of Set 4 | kashi
# Processing Record 15 of Set 4 | sorland
# Processing Record 16 of Set 4 | kihei
# Processing Record 17 of Set 4 | jamame
# Processing Record 18 of Set 4 | dunedin
# Processing Record 19 of Set 4 | isangel
# Processing Record 20 of Set 4 | upington
# Processing Record 21 of Set 4 | ponorogo
# Processing Record 22 of Set 4 | gulu
# Processing Record 23 of Set 4 | hami
# Processing Record 24 of Set 4 | vierzon
# Processing Record 25 of Set 4 | sisimiut
# Processing Record 26 of Set 4 | esperance
# Processing Record 27 of Set 4 | shaunavon
# Processing Record 28 of Set 4 | zeya
# Processing Record 29 of Set 4 | mehamn
# Processing Record 30 of Set 4 | tuatapere
# Processing Record 31 of Set 4 | kenora
# Processing Record 32 of Set 4 | okhotsk
# Processing Record 33 of Set 4 | grand gaube
# Processing Record 34 of Set 4 | bilma
# Processing Record 35 of Set 4 | makurdi
# Processing Record 36 of Set 4 | sedelnikovo
# City not found. Skipping...
# Processing Record 37 of Set 4 | brasy
# Processing Record 38 of Set 4 | nishihara
# Processing Record 39 of Set 4 | verkhoyansk
# Processing Record 40 of Set 4 | tilichiki
# Processing Record 41 of Set 4 | aklavik
# Processing Record 42 of Set 4 | sonoita
# Processing Record 43 of Set 4 | ostersund
# Processing Record 44 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 45 of Set 4 | husavik
# Processing Record 46 of Set 4 | pangnirtung
# Processing Record 47 of Set 4 | ozinki
# Processing Record 48 of Set 4 | egvekinot
# Processing Record 49 of Set 4 | kaeo
# Processing Record 50 of Set 4 | talnakh
# Processing Record 1 of Set 5 | maniitsoq
# Processing Record 2 of Set 5 | henzada
# City not found. Skipping...
# Processing Record 3 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 5 | altay
# Processing Record 5 of Set 5 | longyearbyen
# Processing Record 6 of Set 5 | panaba
# Processing Record 7 of Set 5 | yabrud
# Processing Record 8 of Set 5 | zhuhai
# Processing Record 9 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 10 of Set 5 | xining
# Processing Record 11 of Set 5 | megalopoli
# Processing Record 12 of Set 5 | isiolo
# Processing Record 13 of Set 5 | chabahar
# Processing Record 14 of Set 5 | nara
# Processing Record 15 of Set 5 | boguchany
# Processing Record 16 of Set 5 | lebu
# Processing Record 17 of Set 5 | east london
# Processing Record 18 of Set 5 | linares
# Processing Record 19 of Set 5 | nhulunbuy
# Processing Record 20 of Set 5 | bellview
# Processing Record 21 of Set 5 | pacasmayo
# Processing Record 22 of Set 5 | saint-pierre
# Processing Record 23 of Set 5 | acapulco
# Processing Record 24 of Set 5 | asau
# Processing Record 25 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 5 | kloulklubed
# Processing Record 27 of Set 5 | lompoc
# Processing Record 28 of Set 5 | hasaki
# Processing Record 29 of Set 5 | gizo
# Processing Record 30 of Set 5 | sassandra
# Processing Record 31 of Set 5 | liverpool
# Processing Record 32 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 5 | falam
# Processing Record 34 of Set 5 | aitape
# Processing Record 35 of Set 5 | klaksvik
# Processing Record 36 of Set 5 | aakirkeby
# City not found. Skipping...
# Processing Record 37 of Set 5 | fortuna
# Processing Record 38 of Set 5 | chaa-khol
# City not found. Skipping...
# Processing Record 39 of Set 5 | manado
# Processing Record 40 of Set 5 | kapit
# Processing Record 41 of Set 5 | ulaanbaatar
# Processing Record 42 of Set 5 | sechura
# Processing Record 43 of Set 5 | ribeira grande
# Processing Record 44 of Set 5 | kolosovka
# Processing Record 45 of Set 5 | palekh
# Processing Record 46 of Set 5 | trezzo
# City not found. Skipping...
# Processing Record 47 of Set 5 | manggar
# Processing Record 48 of Set 5 | horodyshche
# Processing Record 49 of Set 5 | humaita
# Processing Record 50 of Set 5 | carballo
# Processing Record 1 of Set 6 | guaruja
# Processing Record 2 of Set 6 | lata
# Processing Record 3 of Set 6 | kawana waters
# City not found. Skipping...
# Processing Record 4 of Set 6 | melfort
# Processing Record 5 of Set 6 | asbury park
# Processing Record 6 of Set 6 | codrington
# Processing Record 7 of Set 6 | ilulissat
# Processing Record 8 of Set 6 | jequitinhonha
# Processing Record 9 of Set 6 | edson
# Processing Record 10 of Set 6 | pangai
# Processing Record 11 of Set 6 | broken hill
# Processing Record 12 of Set 6 | pilar
# Processing Record 13 of Set 6 | aldan
# Processing Record 14 of Set 6 | vila franca do campo
# Processing Record 15 of Set 6 | comodoro rivadavia
# Processing Record 16 of Set 6 | chuy
# Processing Record 17 of Set 6 | lima
# Processing Record 18 of Set 6 | tabas
# Processing Record 19 of Set 6 | hambantota
# Processing Record 20 of Set 6 | lumphat
# Processing Record 21 of Set 6 | bara
# Processing Record 22 of Set 6 | bulgan
# Processing Record 23 of Set 6 | ust-kuyga
# Processing Record 24 of Set 6 | santiago del estero
# Processing Record 25 of Set 6 | neuquen
# Processing Record 26 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 6 | cacequi
# Processing Record 28 of Set 6 | tuy hoa
# Processing Record 29 of Set 6 | hualmay
# Processing Record 30 of Set 6 | sitka
# Processing Record 31 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 6 | santa maria
# Processing Record 33 of Set 6 | belmonte
# Processing Record 34 of Set 6 | puerto escondido
# Processing Record 35 of Set 6 | kismayo
# Processing Record 36 of Set 6 | fallon
# Processing Record 37 of Set 6 | mayumba
# Processing Record 38 of Set 6 | repalle
# Processing Record 39 of Set 6 | tongling
# Processing Record 40 of Set 6 | sao joao da barra
# Processing Record 41 of Set 6 | pevek
# Processing Record 42 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 43 of Set 6 | karakendzha
# City not found. Skipping...
# Processing Record 44 of Set 6 | collie
# Processing Record 45 of Set 6 | seoul
# Processing Record 46 of Set 6 | mapiripan
# Processing Record 47 of Set 6 | maceio
# Processing Record 48 of Set 6 | umm lajj
# Processing Record 49 of Set 6 | rawson
# Processing Record 50 of Set 6 | riohacha
# Processing Record 1 of Set 7 | cartagena
# Processing Record 2 of Set 7 | zachagansk
# City not found. Skipping...
# Processing Record 3 of Set 7 | severo-kurilsk
# Processing Record 4 of Set 7 | torbay
# Processing Record 5 of Set 7 | san patricio
# Processing Record 6 of Set 7 | pudozh
# Processing Record 7 of Set 7 | katherine
# Processing Record 8 of Set 7 | vila velha
# Processing Record 9 of Set 7 | yashkul
# Processing Record 10 of Set 7 | lagos
# Processing Record 11 of Set 7 | yellandu
# Processing Record 12 of Set 7 | ancud
# Processing Record 13 of Set 7 | tigre
# Processing Record 14 of Set 7 | olafsvik
# Processing Record 15 of Set 7 | nushki
# Processing Record 16 of Set 7 | airai
# Processing Record 17 of Set 7 | richards bay
# Processing Record 18 of Set 7 | clyde river
# Processing Record 19 of Set 7 | hanmer springs
# Processing Record 20 of Set 7 | touros
# Processing Record 21 of Set 7 | yeehaw junction
# City not found. Skipping...
# Processing Record 22 of Set 7 | meulaboh
# Processing Record 23 of Set 7 | mackenzie
# Processing Record 24 of Set 7 | creel
# Processing Record 25 of Set 7 | ambunti
# Processing Record 26 of Set 7 | iquitos
# Processing Record 27 of Set 7 | beloha
# Processing Record 28 of Set 7 | wanlaweyn
# Processing Record 29 of Set 7 | davila
# Processing Record 30 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 7 | mitsamiouli
# Processing Record 32 of Set 7 | denpasar
# Processing Record 33 of Set 7 | fukue
# Processing Record 34 of Set 7 | kedrovyy
# Processing Record 35 of Set 7 | lumatil
# Processing Record 36 of Set 7 | vao
# Processing Record 37 of Set 7 | port blair
# Processing Record 38 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 39 of Set 7 | sulangan
# Processing Record 40 of Set 7 | yinchuan
# Processing Record 41 of Set 7 | nanortalik
# Processing Record 42 of Set 7 | quelimane
# Processing Record 43 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 7 | cockburn town
# Processing Record 45 of Set 7 | port elizabeth
# Processing Record 46 of Set 7 | ronne
# Processing Record 47 of Set 7 | pacific grove
# Processing Record 48 of Set 7 | den helder
# Processing Record 49 of Set 7 | sioux lookout
# Processing Record 50 of Set 7 | oros
# Processing Record 1 of Set 8 | porto novo
# Processing Record 2 of Set 8 | weener
# Processing Record 3 of Set 8 | baghdad
# Processing Record 4 of Set 8 | santiago
# Processing Record 5 of Set 8 | dvinskoy
# Processing Record 6 of Set 8 | pitimbu
# Processing Record 7 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 8 | riyadh
# Processing Record 9 of Set 8 | dourbali
# Processing Record 10 of Set 8 | honningsvag
# Processing Record 11 of Set 8 | ndele
# Processing Record 12 of Set 8 | geraldton
# Processing Record 13 of Set 8 | saint-francois
# Processing Record 14 of Set 8 | teahupoo
# Processing Record 15 of Set 8 | henties bay
# Processing Record 16 of Set 8 | hobyo
# Processing Record 17 of Set 8 | antalaha
# Processing Record 18 of Set 8 | babu
# Processing Record 19 of Set 8 | tual
# Processing Record 20 of Set 8 | cayenne
# Processing Record 21 of Set 8 | terme
# Processing Record 22 of Set 8 | chenzhou
# Processing Record 23 of Set 8 | rio grande
# Processing Record 24 of Set 8 | ust-tsilma
# Processing Record 25 of Set 8 | sao filipe
# Processing Record 26 of Set 8 | west wendover
# Processing Record 27 of Set 8 | klyuchi
# Processing Record 28 of Set 8 | kedainiai
# Processing Record 29 of Set 8 | belyy yar
# Processing Record 30 of Set 8 | lerwick
# Processing Record 31 of Set 8 | santomera
# Processing Record 32 of Set 8 | marzuq
# Processing Record 33 of Set 8 | trincomalee
# Processing Record 34 of Set 8 | norfolk
# Processing Record 35 of Set 8 | otradnoye
# Processing Record 36 of Set 8 | baculin
# Processing Record 37 of Set 8 | poronaysk
# Processing Record 38 of Set 8 | komsomolskiy
# Processing Record 39 of Set 8 | preobrazheniye
# Processing Record 40 of Set 8 | novi pazar
# Processing Record 41 of Set 8 | naze
# Processing Record 42 of Set 8 | walvis bay
# Processing Record 43 of Set 8 | buraydah
# Processing Record 44 of Set 8 | alta floresta
# Processing Record 45 of Set 8 | shimoda
# Processing Record 46 of Set 8 | ahipara
# Processing Record 47 of Set 8 | rivne
# Processing Record 48 of Set 8 | jaipur
# Processing Record 49 of Set 8 | arroyo
# Processing Record 50 of Set 8 | druzhba
# Processing Record 1 of Set 9 | vashkivtsi
# Processing Record 2 of Set 9 | san martin
# Processing Record 3 of Set 9 | abha
# Processing Record 4 of Set 9 | tukrah
# Processing Record 5 of Set 9 | tiarei
# Processing Record 6 of Set 9 | la orilla
# Processing Record 7 of Set 9 | broome
# Processing Record 8 of Set 9 | chardara
# Processing Record 9 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 10 of Set 9 | kirakira
# Processing Record 11 of Set 9 | bambanglipuro
# Processing Record 12 of Set 9 | can
# Processing Record 13 of Set 9 | bandarbeyla
# Processing Record 14 of Set 9 | carutapera
# Processing Record 15 of Set 9 | odweyne
# Processing Record 16 of Set 9 | necochea
# Processing Record 17 of Set 9 | tirumullaivasal
# Processing Record 18 of Set 9 | westport
# Processing Record 19 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 9 | bull savanna
# Processing Record 21 of Set 9 | binzhou
# Processing Record 22 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 23 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 9 | gangotri
# City not found. Skipping...
# Processing Record 25 of Set 9 | aligudarz
# Processing Record 26 of Set 9 | general pico
# Processing Record 27 of Set 9 | verkhnyaya inta
# Processing Record 28 of Set 9 | mao
# Processing Record 29 of Set 9 | mnogovershinnyy
# Processing Record 30 of Set 9 | san cristobal
# Processing Record 31 of Set 9 | sheltozero
# Processing Record 32 of Set 9 | agadir
# Processing Record 33 of Set 9 | brewster
# Processing Record 34 of Set 9 | amahai
# Processing Record 35 of Set 9 | tura
# Processing Record 36 of Set 9 | celestun
# Processing Record 37 of Set 9 | dawei
# Processing Record 38 of Set 9 | santa cruz
# Processing Record 39 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 40 of Set 9 | santa luzia
# Processing Record 41 of Set 9 | zyryanka
# Processing Record 42 of Set 9 | lorengau
# Processing Record 43 of Set 9 | pisco
# Processing Record 44 of Set 9 | xinqing
# Processing Record 45 of Set 9 | katsuura
# Processing Record 46 of Set 9 | port shepstone
# Processing Record 47 of Set 9 | hervey bay
# Processing Record 48 of Set 9 | hazleton
# Processing Record 49 of Set 9 | northam
# Processing Record 50 of Set 9 | pampa
# Processing Record 1 of Set 10 | goundam
# Processing Record 2 of Set 10 | zabolotovka
# Processing Record 3 of Set 10 | niamey
# Processing Record 4 of Set 10 | najran
# Processing Record 5 of Set 10 | tambun
# Processing Record 6 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 7 of Set 10 | japura
# Processing Record 8 of Set 10 | yerofey pavlovich
# Processing Record 9 of Set 10 | liminangcong
# City not found. Skipping...
# Processing Record 10 of Set 10 | liancheng
# Processing Record 11 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 12 of Set 10 | hofn
# Processing Record 13 of Set 10 | sao lourenco do sul
# Processing Record 14 of Set 10 | turukhansk
# Processing Record 15 of Set 10 | guicheng
# City not found. Skipping...
# Processing Record 16 of Set 10 | vestmannaeyjar
# Processing Record 17 of Set 10 | chitipa
# Processing Record 18 of Set 10 | takoradi
# Processing Record 19 of Set 10 | naifaru
# Processing Record 20 of Set 10 | puerto del rosario
# Processing Record 21 of Set 10 | poso
# Processing Record 22 of Set 10 | pyapon
# Processing Record 23 of Set 10 | lavrentiya
# Processing Record 24 of Set 10 | iracoubo
# Processing Record 25 of Set 10 | havre-saint-pierre
# Processing Record 26 of Set 10 | great falls
# Processing Record 27 of Set 10 | atar
# Processing Record 28 of Set 10 | lobito
# Processing Record 29 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 10 | omsukchan
# Processing Record 31 of Set 10 | kununurra
# Processing Record 32 of Set 10 | omboue
# Processing Record 33 of Set 10 | bababe
# City not found. Skipping...
# Processing Record 34 of Set 10 | prince rupert
# Processing Record 35 of Set 10 | qaqortoq
# Processing Record 36 of Set 10 | dangtu
# Processing Record 37 of Set 10 | camacha
# Processing Record 38 of Set 10 | bonavista
# Processing Record 39 of Set 10 | parati
# Processing Record 40 of Set 10 | port hedland
# Processing Record 41 of Set 10 | sergeyevka
# Processing Record 42 of Set 10 | mogochin
# City not found. Skipping...
# Processing Record 43 of Set 10 | kirensk
# Processing Record 44 of Set 10 | odienne
# Processing Record 45 of Set 10 | namibe
# Processing Record 46 of Set 10 | norman wells
# Processing Record 47 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record 48 of Set 10 | yeniseysk
# Processing Record 49 of Set 10 | vodnyy
# Processing Record 50 of Set 10 | kavieng
# Processing Record 1 of Set 11 | port keats
# Processing Record 2 of Set 11 | yanam
# Processing Record 3 of Set 11 | knysna
# Processing Record 4 of Set 11 | merauke
# Processing Record 5 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 11 | port-gentil
# Processing Record 7 of Set 11 | chimbote
# Processing Record 8 of Set 11 | tuensang
# Processing Record 9 of Set 11 | solnechnyy
# Processing Record 10 of Set 11 | astoria
# Processing Record 11 of Set 11 | byron bay
# Processing Record 12 of Set 11 | manokwari
# Processing Record 13 of Set 11 | guerrero negro
# Processing Record 14 of Set 11 | sao miguel do araguaia
# Processing Record 15 of Set 11 | kalawit
# Processing Record 16 of Set 11 | la ronge
# Processing Record 17 of Set 11 | luanda
# Processing Record 18 of Set 11 | lebedinyy
# Processing Record 19 of Set 11 | hendersonville
# Processing Record 20 of Set 11 | leh
# Processing Record 21 of Set 11 | satwas
# Processing Record 22 of Set 11 | saldanha
# Processing Record 23 of Set 11 | swidnik
# Processing Record 24 of Set 11 | peniche
# Processing Record 25 of Set 11 | aripuana
# Processing Record 26 of Set 11 | yumen
# Processing Record 27 of Set 11 | senanga
# Processing Record 28 of Set 11 | kiama
# Processing Record 29 of Set 11 | mutsamudu
# City not found. Skipping...
# Processing Record 30 of Set 11 | guspini
# Processing Record 31 of Set 11 | honiara
# Processing Record 32 of Set 11 | imbituba
# Processing Record 33 of Set 11 | bilibino
# Processing Record 34 of Set 11 | lakes entrance
# Processing Record 35 of Set 11 | college
# Processing Record 36 of Set 11 | sao gabriel da cachoeira
# Processing Record 37 of Set 11 | fatehpur
# Processing Record 38 of Set 11 | alvaraes
# Processing Record 39 of Set 11 | orlik
# Processing Record 40 of Set 11 | la colorada
# Processing Record 41 of Set 11 | twin falls
# Processing Record 42 of Set 11 | rio grande city
# Processing Record 43 of Set 11 | aloleng
# Processing Record 44 of Set 11 | san andres
# Processing Record 45 of Set 11 | sanming
# Processing Record 46 of Set 11 | tommot
# Processing Record 47 of Set 11 | saint anthony
# Processing Record 48 of Set 11 | san juan
# Processing Record 49 of Set 11 | carnarvon
# Processing Record 50 of Set 11 | khoy
# Processing Record 1 of Set 12 | ponta delgada
# Processing Record 2 of Set 12 | nha trang
# Processing Record 3 of Set 12 | lalibela
# Processing Record 4 of Set 12 | belgrade
# Processing Record 5 of Set 12 | flinders
# Processing Record 6 of Set 12 | gap
# Processing Record 7 of Set 12 | deputatskiy
# Processing Record 8 of Set 12 | inhambane
# Processing Record 9 of Set 12 | goderich
# Processing Record 10 of Set 12 | boden
# Processing Record 11 of Set 12 | kolvereid
# Processing Record 12 of Set 12 | aksarka
# Processing Record 13 of Set 12 | phalaborwa
# Processing Record 14 of Set 12 | tessalit
# Processing Record 15 of Set 12 | andippatti
# Processing Record 16 of Set 12 | srednekolymsk
# Processing Record 17 of Set 12 | tabuk
# Processing Record 18 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 12 | taltal
# Processing Record 20 of Set 12 | mankato
# Processing Record 21 of Set 12 | dingle
# Processing Record 22 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 23 of Set 12 | ossora
# Processing Record 24 of Set 12 | pimenteiras
# Processing Record 25 of Set 12 | makakilo city
# Processing Record 26 of Set 12 | naryan-mar
# Processing Record 27 of Set 12 | zelenogorskiy
# Processing Record 28 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 29 of Set 12 | ithaca
# Processing Record 30 of Set 12 | fare
# Processing Record 31 of Set 12 | adrar
# Processing Record 32 of Set 12 | urdoma
# Processing Record 33 of Set 12 | wainwright
# Processing Record 34 of Set 12 | awjilah
# Processing Record 35 of Set 12 | bose
# Processing Record 36 of Set 12 | kananga
# Processing Record 37 of Set 12 | whitehorse
# Processing Record 38 of Set 12 | sabha
# Processing Record 39 of Set 12 | sangar
# Processing Record 40 of Set 12 | muncar
# Processing Record 41 of Set 12 | kaitangata
# Processing Record 42 of Set 12 | surt
# Processing Record 43 of Set 12 | wenling
# Processing Record 44 of Set 12 | jagannathpur
# Processing Record 45 of Set 12 | rocha
# Processing Record 46 of Set 12 | yulara
# Processing Record 47 of Set 12 | chipinge
# Processing Record 48 of Set 12 | the pas
# Processing Record 49 of Set 12 | bend
# Processing Record 50 of Set 12 | taoudenni
# Processing Record 1 of Set 13 | cachoeirinha
# Processing Record 2 of Set 13 | carroll
# Processing Record 3 of Set 13 | iquique
# Processing Record 4 of Set 13 | korla
# Processing Record 5 of Set 13 | kimbe
# Processing Record 6 of Set 13 | gobabis
# Processing Record 7 of Set 13 | kargil
# Processing Record 8 of Set 13 | sinnamary
# Processing Record 9 of Set 13 | labuhan
# Processing Record 10 of Set 13 | eyl
# Processing Record 11 of Set 13 | banjar
# Processing Record 12 of Set 13 | mocuba
# Processing Record 13 of Set 13 | mount gambier
# Processing Record 14 of Set 13 | cacoal
# Processing Record 15 of Set 13 | tucuman
# Processing Record 16 of Set 13 | san quintin
# Processing Record 17 of Set 13 | arona
# Processing Record 18 of Set 13 | santa rosalia
# Processing Record 19 of Set 13 | jiuquan
# Processing Record 20 of Set 13 | fort-shevchenko
# Processing Record 21 of Set 13 | nawa
# Processing Record 22 of Set 13 | bollnas
# Processing Record 23 of Set 13 | poplar bluff
# Processing Record 24 of Set 13 | noyabrsk
# Processing Record 25 of Set 13 | puerto leguizamo
# Processing Record 26 of Set 13 | alice springs
# Processing Record 27 of Set 13 | kupang
# Processing Record 28 of Set 13 | gold coast
# Processing Record 29 of Set 13 | lingao
# Processing Record 30 of Set 13 | nandu
# Processing Record 31 of Set 13 | raudeberg
# Processing Record 32 of Set 13 | turbat
# Processing Record 33 of Set 13 | catamarca
# Processing Record 34 of Set 13 | ettaiyapuram
# Processing Record 35 of Set 13 | port macquarie
# Processing Record 36 of Set 13 | middletown
# Processing Record 37 of Set 13 | uni
# Processing Record 38 of Set 13 | constanza
# Processing Record 39 of Set 13 | poli
# Processing Record 40 of Set 13 | tabulbah
# City not found. Skipping...
# Processing Record 41 of Set 13 | brownsville
# Processing Record 42 of Set 13 | churapcha
# Processing Record 43 of Set 13 | nabire
# Processing Record 44 of Set 13 | shakawe
# Processing Record 45 of Set 13 | nyuksenitsa
# Processing Record 46 of Set 13 | bolshiye kaybitsy
# City not found. Skipping...
# Processing Record 47 of Set 13 | pauini
# Processing Record 48 of Set 13 | christchurch
# Processing Record 49 of Set 13 | mossendjo
# Processing Record 50 of Set 13 | ambovombe
# Processing Record 1 of Set 14 | pussi
# Processing Record 2 of Set 14 | vila
# Processing Record 3 of Set 14 | vanavara
# Processing Record 4 of Set 14 | killybegs
# Processing Record 5 of Set 14 | reguengos de monsaraz
# Processing Record 6 of Set 14 | hornepayne
# Processing Record 7 of Set 14 | copiapo
# Processing Record 8 of Set 14 | dubovyy umet
# Processing Record 9 of Set 14 | kavaratti
# Processing Record 10 of Set 14 | yago
# Processing Record 11 of Set 14 | sun valley
# Processing Record 12 of Set 14 | serramanna
# Processing Record 13 of Set 14 | houston
# Processing Record 14 of Set 14 | viedma
# Processing Record 15 of Set 14 | ondangwa
# Processing Record 16 of Set 14 | tucupita
# Processing Record 17 of Set 14 | kamaishi
# Processing Record 18 of Set 14 | havoysund
# Processing Record 19 of Set 14 | astana
# Processing Record 20 of Set 14 | mega
# Processing Record 21 of Set 14 | albion
# Processing Record 22 of Set 14 | andenes
# Processing Record 23 of Set 14 | ust-nera
# Processing Record 24 of Set 14 | bundaberg
# Processing Record 25 of Set 14 | bokspits
# City not found. Skipping...
# Processing Record 26 of Set 14 | loreto
# Processing Record 27 of Set 14 | port arthur
# Processing Record 28 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 29 of Set 14 | la primavera
# Processing Record 30 of Set 14 | payyannur
# Processing Record 31 of Set 14 | kawalu
# Processing Record 32 of Set 14 | jinchang
# Processing Record 33 of Set 14 | tortoli
# Processing Record 34 of Set 14 | oyem
# Processing Record 35 of Set 14 | senador pompeu
# Processing Record 36 of Set 14 | choix
# Processing Record 37 of Set 14 | diveyevo
# Processing Record 38 of Set 14 | yenagoa
# Processing Record 39 of Set 14 | faya
# Processing Record 40 of Set 14 | kodinsk
# Processing Record 41 of Set 14 | shache
# Processing Record 42 of Set 14 | morondava
# Processing Record 43 of Set 14 | springdale
# Processing Record 44 of Set 14 | petropavlovka
# Processing Record 45 of Set 14 | nantucket
# Processing Record 46 of Set 14 | yambio
# Processing Record 47 of Set 14 | srivardhan
# Processing Record 48 of Set 14 | port hardy
# Processing Record 49 of Set 14 | angoche
# Processing Record 50 of Set 14 | buchanan
# Processing Record 1 of Set 15 | krasnoyarskiy
# Processing Record 2 of Set 15 | katima mulilo
# Processing Record 3 of Set 15 | poyarkovo
# Processing Record 4 of Set 15 | olga
# Processing Record 5 of Set 15 | agropoli
# Processing Record 6 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 7 of Set 15 | ellensburg
# Processing Record 8 of Set 15 | hartford
# Processing Record 9 of Set 15 | jumla
# Processing Record 10 of Set 15 | wanning
# Processing Record 11 of Set 15 | samfya
# Processing Record 12 of Set 15 | san vicente
# Processing Record 13 of Set 15 | axim
# Processing Record 14 of Set 15 | kisesa
# Processing Record 15 of Set 15 | wyndham
# Processing Record 16 of Set 15 | barcelos
# Processing Record 17 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 18 of Set 15 | bogotol
# Processing Record 19 of Set 15 | graaff-reinet
# Processing Record 20 of Set 15 | tamahu
# Processing Record 21 of Set 15 | avera
# Processing Record 22 of Set 15 | krasnoselkup
# Processing Record 23 of Set 15 | mandalgovi
# Processing Record 24 of Set 15 | zaykovo
# Processing Record 25 of Set 15 | bolshaya glushitsa
# Processing Record 26 of Set 15 | chaman
# Processing Record 27 of Set 15 | port augusta
# Processing Record 28 of Set 15 | porosozero
# Processing Record 29 of Set 15 | price
# Processing Record 30 of Set 15 | umm kaddadah
# Processing Record 31 of Set 15 | sahrak
# City not found. Skipping...
# Processing Record 32 of Set 15 | rumia
# Processing Record 33 of Set 15 | sept-iles
# Processing Record 34 of Set 15 | lebanon
# Processing Record 35 of Set 15 | youhao
# Processing Record 36 of Set 15 | moose factory
# Processing Record 37 of Set 15 | zaraza
# Processing Record 38 of Set 15 | bosaso
# Processing Record 39 of Set 15 | cedar city
# Processing Record 40 of Set 15 | blumenau
# Processing Record 41 of Set 15 | coldwater
# Processing Record 42 of Set 15 | nordkisa
# City not found. Skipping...
# Processing Record 43 of Set 15 | katobu
# Processing Record 44 of Set 15 | washington
# Processing Record 45 of Set 15 | khandyga
# Processing Record 46 of Set 15 | maputo
# Processing Record 47 of Set 15 | kasongo
# Processing Record 48 of Set 15 | keshod
# Processing Record 49 of Set 15 | mopipi
# Processing Record 50 of Set 15 | ouadda
# Processing Record 1 of Set 16 | yar-sale
# Processing Record 2 of Set 16 | lewiston
# Processing Record 3 of Set 16 | fort saint john
# City not found. Skipping...
# Processing Record 4 of Set 16 | almere
# Processing Record 5 of Set 16 | la asuncion
# Processing Record 6 of Set 16 | namie
# Processing Record 7 of Set 16 | white oak
# Processing Record 8 of Set 16 | canavieiras
# Processing Record 9 of Set 16 | sinnai
# Processing Record 10 of Set 16 | portland
# Processing Record 11 of Set 16 | binghamton
# Processing Record 12 of Set 16 | lagunas
# Processing Record 13 of Set 16 | diepenbeek
# Processing Record 14 of Set 16 | dunbar
# Processing Record 15 of Set 16 | lewisporte
# Processing Record 16 of Set 16 | catuday
# Processing Record 17 of Set 16 | kontagora
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Le Port      RE -20.9373   55.2919     85.96        63           2
# 1            Mecca      SA  21.4267   39.8261     65.59        47           2
# 2          Rikitea      PF -23.1203 -134.9692     77.88        73          94
# 3           Barrow      US  71.2906 -156.7887     -2.18        71         100
# 4           Hobart      AU -42.8794  147.3294     74.01        62          75
# 5           Fuling      CN  29.7022  107.3919     41.83        95         100
# 6        Belchatow      PL  51.3688   19.3567     31.05        85         100
# 7        Busselton      AU -33.6500  115.3333    100.04        42          94
# 8  Haines Junction      CA  60.7522 -137.5108     16.93        97         100
# 9        Kathmandu      NP  27.7167   85.3167     55.62        54          20
#
#    Wind Speed Current Description
# 0        2.93           clear sky
# 1        7.23           clear sky
# 2       14.07     overcast clouds
# 3       13.80                haze
# 4        1.01       broken clouds
# 5        1.19     overcast clouds
# 6       10.13     overcast clouds
# 7        9.17     overcast clouds
# 8        3.94          light snow
# 9        2.30                haze

# %%
 # Create the output file (CSV).
output_data_file = 'weatherPy_Database.csv'
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
